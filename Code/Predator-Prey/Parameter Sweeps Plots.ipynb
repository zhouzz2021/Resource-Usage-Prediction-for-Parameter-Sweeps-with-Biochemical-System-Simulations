# %%
#Imports
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 150
import numpy as np
import math
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
sns.set_style("whitegrid")

# %%
# Parameter sweeps dataset
parasweep = pd.read_csv("fox_rabbit3D_multipara.csv")

# %%
parasweep
# Out:
#           runtime  The number of rabbits  The number of foxes  r_birth  \
# 0        0.544513           1.157000e+03          1152.000000      5.0
# 1        0.391062           1.139000e+03           563.000000      5.0
# 2        0.371088           3.011000e+03           253.000000      5.0
# 3        0.198700           5.800000e+02            80.000000      5.0
# 4        0.437672           7.570000e+02           717.000000      5.0
# ...           ...                    ...                  ...      ...
# 431995   2.411189           1.102857e+03           893.142857    100.0
# 431996   2.469272           3.614286e+02          1532.571429    100.0
# 431997   2.330160           6.644286e+02           805.428571    100.0
# 431998  20.024446           1.067954e+07            53.285714    100.0
# 431999  20.031058           1.085760e+07             0.000000    100.0
#
#         f_birth     f_death  number_of_trajectories  Timespan
# ...

# %%
# Parameter sweeps, displayed with three parameters
fig = plt.figure(figsize = (12,8))
fig.tight_layout()
ax = fig.add_subplot(projection='3d')
ax.scatter(xs=parasweep["r_birth"], ys=parasweep["f_birth"], zs=parasweep["f_death"],marker="*", s=0.1)
plt.tick_params(labelsize=8)
ax.set_xlabel("r_birth",fontsize=12)
ax.set_ylabel("f_birth",labelpad=7,fontsize=12)
ax.set_zlabel("f_death",labelpad=-1.7,fontsize=12)
# Out:
# Text(0.5, 0, 'f_death')

# %%
# Parameter sweeps, displayed with two parameters
sns.set()
sns.scatterplot(x=parasweep["r_birth"], y=parasweep["f_birth"],  s=10)
# Out:
# <AxesSubplot:xlabel='r_birth', ylabel='f_birth'>

# %%
# Parameter sweeps, displayed with two parameters
sns.scatterplot(x=parasweep["r_birth"], y=parasweep["f_death"],  s=10)
# Out:
# <AxesSubplot:xlabel='r_birth', ylabel='f_death'>

# %%
# Parameter sweeps, displayed with two parameters
sns.scatterplot(x=parasweep["f_birth"], y=parasweep["f_death"], s=10)
# Out:
# <AxesSubplot:xlabel='f_birth', ylabel='f_death'>

# %%
# Hyperparameter sweeps
sns.scatterplot(x=parasweep["number_of_trajectories"], y=parasweep["Timespan"])
# Out:
# <AxesSubplot:xlabel='number_of_trajectories', ylabel='Timespan'>
