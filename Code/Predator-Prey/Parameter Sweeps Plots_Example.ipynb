# %%
#Imports
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 150
import numpy as np
import math
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
sns.set_style("whitegrid")

# %%
# Model parameter sweeps example
parasweep = pd.read_csv("fox_rabbit_test.csv")

# %%
parasweep
# Out:
#       runtime  The number of rabbits  The number of foxes  r_birth  f_birth  \
# 0    0.383017            1651.333333          1728.000000     10.0    0.010
# 1    0.380584             792.000000          1109.666667     10.0    0.010
# 2    0.376739            1077.000000           849.666667     10.0    0.010
# 3    0.377684             679.333333           716.000000     10.0    0.010
# 4    0.378354             515.333333          2030.333333     10.0    0.010
# ..        ...                    ...                  ...      ...      ...
# 120  0.403689             576.000000           826.000000     15.0    0.015
# 121  0.399810            1146.666667          1121.666667     15.0    0.015
# 122  0.399855             981.666667           845.000000     15.0    0.015
# 123  0.399634             903.000000          1285.666667     15.0    0.015
# 124  0.398938             699.333333           662.000000     15.0    0.015
#
#      f_death  number_of_trajectories  Timespan
# ...

# %%
# Parameter sweeps, displayed with three parameters
fig = plt.figure(figsize = (12,8))
fig.tight_layout()
ax = fig.add_subplot(projection='3d')
ax.scatter(xs=parasweep["r_birth"], ys=parasweep["f_birth"], zs=parasweep["f_death"],marker="*")
plt.tick_params(labelsize=8)
ax.set_xlabel("r_birth",fontsize=12)
ax.set_ylabel("f_birth",labelpad=7,fontsize=12)
ax.set_zlabel("f_death",labelpad=-1.7,fontsize=12)
# Out:
# Text(0.5, 0, 'f_death')

# %%
# Parameter sweeps, displayed with two parameters
sns.set(font_scale = 1.5)
fig, ax = plt.subplots(1,3, figsize=(12, 8))
axesSub = sns.scatterplot(x=parasweep["r_birth"], y=parasweep["f_birth"], ax=ax[0], s=100)
axesSub = sns.scatterplot(x=parasweep["f_death"], y=parasweep["r_birth"], ax=ax[1], s=100)
axesSub = sns.scatterplot(x=parasweep["f_birth"], y=parasweep["f_death"], ax=ax[2], s=100)
fig.tight_layout()
