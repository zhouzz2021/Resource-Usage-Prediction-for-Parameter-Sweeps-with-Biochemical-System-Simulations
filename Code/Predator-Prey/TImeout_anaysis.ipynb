# %%
#Imports
import pandas as pd
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.rcParams['figure.dpi'] = 150
import numpy as np
import math
from scipy import stats
from mpl_toolkits.mplot3d import Axes3D
sns.set()

# %%
parasweep = pd.read_csv("fox_rabbit3D_multipara_dask1.csv")

# %%
parasweep.shape
# Out:
# (432000, 8)

# %%
parasweep
# Out:
#           runtime  The number of rabbits  The number of foxes  r_birth  \
# 0        0.544513           1.157000e+03          1152.000000      5.0
# 1        0.391062           1.139000e+03           563.000000      5.0
# 2        0.371088           3.011000e+03           253.000000      5.0
# 3        0.198700           5.800000e+02            80.000000      5.0
# 4        0.437672           7.570000e+02           717.000000      5.0
# ...           ...                    ...                  ...      ...
# 431995   2.411189           1.102857e+03           893.142857    100.0
# 431996   2.469272           3.614286e+02          1532.571429    100.0
# 431997   2.330160           6.644286e+02           805.428571    100.0
# 431998  20.024446           1.067954e+07            53.285714    100.0
# 431999  20.031058           1.085760e+07             0.000000    100.0
#
#         f_birth     f_death  number_of_trajectories  Timespan
# ...

# %%
sns.scatterplot(x = parasweep["runtime"], y=parasweep["The number of rabbits"])
sns.scatterplot(x = parasweep["runtime"], y=parasweep["The number of foxes"])
plt.legend(["Rabbits", "Foxes"])
plt.ylabel("The number of animals")
# Out:
# Text(0, 0.5, 'The number of animals')

# %%
sns.scatterplot(x = parasweep["runtime"], y=parasweep["The number of rabbits"])
sns.kdeplot(x = parasweep["runtime"], y=parasweep["The number of rabbits"], color = "#fce300")
# Out:
# <AxesSubplot: xlabel='runtime', ylabel='The number of rabbits'>

# %%
sns.scatterplot(x = parasweep["runtime"], y=parasweep["The number of foxes"])
sns.kdeplot(x = parasweep["runtime"], y=parasweep["The number of foxes"], color = "#fce300")
# Out:
# <AxesSubplot: xlabel='runtime', ylabel='The number of foxes'>

# %%
sns.scatterplot(x = parasweep["The number of rabbits"], y=parasweep["The number of foxes"])
sns.kdeplot(x = parasweep["The number of rabbits"], y=parasweep["The number of foxes"], color = "#fce300")
# Out:
# <AxesSubplot: xlabel='The number of rabbits', ylabel='The number of foxes'>
